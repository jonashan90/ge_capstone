# %%
from noaa_sdk import noaa
import requests
import json

# %%
headers = {"token": "xVEIkLnfHyheHhvoheZSxesUerlyrxGN"}
#url = "https://www.ncdc.noaa.gov/cdo-web/api/v2/datasets"
url = "https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&locationid=CITY:US360019&startdate=2010-01-01&enddate=2010-01-02&limit=1000"
#url = "https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCNDMS&locationid=CITY:US360019&startdate=2000-01-01&enddate=2010-01-01&limit=1000"
response = requests.get(url=url, headers=headers)

# %%
json_object = response.json()
print(json_object.keys)
# Out:
# <built-in method keys of dict object at 0x0000000007C4B990>

# %%
print(json_object)
# Out:
# {'metadata': {'resultset': {'offset': 1, 'count': 488, 'limit': 1000}}, 'results': [{'date': '2010-01-01T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:US1NJBG0002', 'attributes': ',,N,', 'value': 74}, {'date': '2010-01-01T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:US1NJBG0002', 'attributes': ',,N,', 'value': 48}, {'date': '2010-01-01T00:00:00', 'datatype': 'WESF', 'station': 'GHCND:US1NJBG0002', 'attributes': ',,N,', 'value': 74}, {'date': '2010-01-01T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:US1NJBG0003', 'attributes': ',,N,', 'value': 69}, {'date': '2010-01-01T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:US1NJBG0003', 'attributes': ',,N,', 'value': 58}, {'date': '2010-01-01T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:US1NJBG0003', 'attributes': ',,N,', 'value': 46}, {'date': '2010-01-01T00:00:00', 'datatype': 'WESD', 'station': 'GHCND:US1NJBG0003', 'attributes': ',,N,', 'value': 61}, {'date': '2010-01-01T00:00:00', 'datatype': 'WESF', 'station': 'GHCND:US1N
# ...

# %%
print(json_object["results"])
# Out:
# [{'date': '2010-01-01T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:US1NJBG0002', 'attributes': ',,N,', 'value': 74}, {'date': '2010-01-01T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:US1NJBG0002', 'attributes': ',,N,', 'value': 48}, {'date': '2010-01-01T00:00:00', 'datatype': 'WESF', 'station': 'GHCND:US1NJBG0002', 'attributes': ',,N,', 'value': 74}, {'date': '2010-01-01T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:US1NJBG0003', 'attributes': ',,N,', 'value': 69}, {'date': '2010-01-01T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:US1NJBG0003', 'attributes': ',,N,', 'value': 58}, {'date': '2010-01-01T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:US1NJBG0003', 'attributes': ',,N,', 'value': 46}, {'date': '2010-01-01T00:00:00', 'datatype': 'WESD', 'station': 'GHCND:US1NJBG0003', 'attributes': ',,N,', 'value': 61}, {'date': '2010-01-01T00:00:00', 'datatype': 'WESF', 'station': 'GHCND:US1NJBG0003', 'attributes': ',,N,', 'value': 69}, {'date': '2010-01-01T00:00:00', 'data
# ...
